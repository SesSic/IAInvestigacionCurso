# %% [markdown]
# # Sesión 9 — Ética, integridad y reproducibilidad científica**Temas:** sesgos, privacidad, autoría y transparencia, Git/GitHub, documentación de notebooks y organización de repositorios**Duración:** 3 horas (2 bloques de 50 min + cierre, con descansos de 15 min)## Objetivo de la sesión- Reconocer sesgos comunes en datos e IA, y riesgos de privacidad- Saber cómo declarar el uso de IA en publicaciones académicas- Crear tu propio repositorio en GitHub con el trabajo del curso- Dejar tu proyecto documentado y reproducible> 💡 Esta sesión tiene menos código y más reflexión + trabajo práctico en GitHub — es la que conecta todo lo técnico con la responsabilidad profesional.

# %% [markdown]
# ---## 🟦 Bloque 1 (50 min) — Sesgos y privacidad

# %% [markdown]
# ### 1.1 ¿Qué es un sesgo en datos?Un modelo o análisis "aprende" lo que hay en los datos — si los datos reflejan una desigualdad o subrepresentación, el resultado la reproduce y a veces la amplifica.**Ejemplos reales:**- Un modelo de diagnóstico médico entrenado mayormente con datos de un grupo etario o género puede fallar en otros grupos- Un sistema de selección de personal entrenado con contrataciones históricas puede replicar sesgos de género o edad de esas contrataciones- Una base de "casos exitosos" en educación que solo incluye una facultad no representa a las demás

# %% [markdown]
# ### 1.2 Revisa tu propia base con esta preguntaPiensa en el dataset que usaste durante el curso (el tuyo o el de ejemplo): **¿qué grupo podría estar sobre-representado o ausente?** ¿Qué pasaría si sacaras conclusiones generales a partir de él?

# %% [markdown]
# **Tu reflexión:***(escribe aquí 2-3 líneas)*

# %% [markdown]
# ### 1.3 Privacidad: qué NO subir a herramientas de IA públicasRegla simple: **si no lo publicarías en una red social, no lo pegues en ChatGPT/Claude/DeepSeek/Gemini gratuitos.****Nunca subas a estas herramientas:**- Nombres reales de pacientes, historias clínicas, diagnósticos identificables- Datos de menores de edad identificables- Información de casos legales en curso con datos de las partes- Cualquier dato que tu institución clasifique como confidencial**Sí puedes usar (anonimizado):**- Datos con nombres reemplazados por códigos ("Paciente 001" en vez del nombre real)- Estadísticas agregadas (promedios, porcentajes) sin identificar personas individuales

# %% [markdown]
# ---### 🧪 Ejercicio 1 — Checklist de privacidadRevisa cualquier archivo que hayas subido a una IA durante el curso. ¿Tenía datos que deberían haber sido anonimizados primero?

# %% [markdown]
# **Tu checklist:**- [ ] Revisé si mis datos tenían nombres reales identificables- [ ] Revisé si mis datos tenían información sensible (salud, legal, menores)- [ ] Si algo era sensible, lo anonimicé antes de usarlo con IA

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟩 Bloque 2 (50 min) — Autoría y transparencia

# %% [markdown]
# ### 2.1 ¿Puedes poner a la IA como autora de un paper?**No.** Las políticas de las principales editoriales (Nature, IEEE, Elsevier, entre otras) coinciden en que la IA **no puede ser autora** porque no puede asumir responsabilidad por el contenido. Pero sí exigen que **declares su uso** si la usaste para redactar, analizar o generar código.

# %% [markdown]
# ### 2.2 Cómo declarar el uso de IA (ejemplo de texto)> "Durante la preparación de este trabajo, el/los autor(es) usó/usaron [nombre de la herramienta] para [tarea específica: redacción, traducción, generación de código, análisis exploratorio]. Después de usar esta herramienta, el/los autor(es) revisó/revisaron y editó/editaron el contenido según fue necesario, y asume/asumen total responsabilidad por el contenido de la publicación."Esto normalmente va en la sección de **Agradecimientos** o **Métodos**, según la revista.

# %% [markdown]
# ### 2.3 Revisita tu ejercicio de sílabo (Sesión 6)Si generaste contenido de sílabo con IA, ¿lo declararías igual en un documento institucional? Reflexiona: la misma lógica de transparencia aplica más allá de los papers — en cualquier documento oficial donde usaste IA como apoyo.

# %% [markdown]
# ---### 🧪 Ejercicio 2 — Redacta tu propia declaración de uso de IABasándote en el ejemplo de arriba, redacta una declaración para algo que hayas hecho con IA durante este curso (el sílabo, un análisis, un gráfico).

# %% [markdown]
# **Tu declaración:***(escribe aquí)*

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟨 Bloque 3 (50 min) — Git/GitHub: crea tu propio repositorio

# %% [markdown]
# ### 3.1 ¿Por qué esto es parte de "ética"?La reproducibilidad **es** un compromiso ético: cualquier persona debería poder revisar tu trabajo y llegar al mismo resultado. Un análisis que solo existe en tu computador, sin documentar, no es verificable por nadie más — ni siquiera por ti mismo dentro de 6 meses.

# %% [markdown]
# ### 3.2 Crea tu cuenta y repositorio (si no lo tienes ya)1. Ve a **github.com** → crea una cuenta gratuita si no tienes2. Clic en **"New"** → nombre sugerido: `mi-investigacion-[tu-tema]`3. Marca **Public**4. Clic en **Create repository**

# %% [markdown]
# ### 3.3 Sube tu trabajo del cursoSube al menos:- El notebook de tu **proyecto** que vienes armando (o cualquiera de los que trabajaste en el curso, con tus propios datos)- Tu archivo de datos (si no es sensible — recuerda el Bloque 1)- Un `README.md` que explique qué es el proyecto**Estructura sugerida de tu README:**```# Nombre de tu proyecto## ¿Qué es esto?Breve descripción de tu análisis/investigación.## DatosDe dónde vienen los datos y qué representan.## Cómo reproducir este análisis1. Abre el notebook en Google Colab2. Ejecuta las celdas en orden3. ...## Uso de IADeclara aquí si usaste IA generativa y para qué (ver Bloque 2).```

# %% [markdown]
# ### 3.4 Ejemplo de un repositorio de investigación realUn proyecto de investigación bien documentado normalmente organiza carpetas así:```proyecto-investigacion/├── README.md              ← qué es, cómo reproducirlo├── datos/                 ← datos crudos y procesados├── notebooks/             ← análisis paso a paso├── resultados/            ← gráficos, tablas finales└── LICENSE                ← términos de uso del código```Esta misma lógica aplica sea tu proyecto de robótica, un estudio clínico, o una revisión de sentencias judiciales — la organización clara es lo que hace que el trabajo sea reutilizable por ti o por otros.

# %% [markdown]
# ---### 🧪 Ejercicio final — Tu repositorio listoConfirma que tu repositorio en GitHub tiene:- [ ] Al menos un notebook subido- [ ] Un README.md que explica el proyecto- [ ] Declaración de uso de IA (si aplica)- [ ] Nombre y estructura claros

# %% [markdown]
# ---## ✅ Cierre de la sesiónHoy lograste:- ✅ Identificar sesgos y riesgos de privacidad en tus propios datos- ✅ Aprender a declarar el uso de IA en publicaciones y documentos oficiales- ✅ Crear tu propio repositorio en GitHub- ✅ Documentar tu trabajo para que sea reproducible**Para la próxima sesión (Proyecto integrador y cierre):** vas a presentar tu propio mini-proyecto, integrando todo lo visto en el curso — trae tu repositorio de GitHub listo.

# %% [markdown]
# # Sesión 7 — IA para revisión y gestión de literatura**Temas:** estrategias de búsqueda, matrices de literatura, extracción asistida, comparación de estudios, verificación de referencias**Duración:** 3 horas (2 bloques de 50 min + cierre, con descansos de 15 min)## Objetivo de la sesión- Diseñar una estrategia de búsqueda efectiva con ayuda de IA- Construir una matriz de literatura (tabla comparativa de papers) con extracción asistida- Verificar que las referencias generadas por IA existan realmente- Aplicar todo esto a un mini-caso de tu propia área, reutilizable en tu investigación real> 💡 **Caso real:** para una revisión sistemática de detección de fallas en líneas de transmisión con drones, se procesaron más de 100 papers siguiendo metodología PRISMA — un proceso que normalmente toma semanas. Hoy van a ver la versión acelerada (pero igual de rigurosa) de ese mismo proceso, aplicada a su propia área, en 3 horas.> ✏️ Igual que la sesión anterior: vas a usar una IA externa (Gemini, Claude, ChatGPT o DeepSeek) y traer resultados de vuelta a este notebook.

# %% [markdown]
# ---## 🟦 Bloque 1 (50 min) — Estrategia de búsqueda con IA

# %% [markdown]
# ### 1.1 El problema de buscar "a lo bruto"Buscar solo "inteligencia artificial en educación" en Google Scholar te da decenas de miles de resultados, la mayoría irrelevantes. Una buena estrategia de búsqueda usa **palabras clave específicas combinadas con operadores** (`AND`, `OR`, comillas para frases exactas).

# %% [markdown]
# ### 1.2 Usa IA para construir tu estrategia de búsqueda**Prompt sugerido** (ajústalo a tu tema real de investigación):> "Soy investigador en [tu área]. Quiero hacer una revisión de literatura sobre [tu tema específico]. Ayúdame a construir 3 cadenas de búsqueda (search strings) para usar en Google Scholar o Scopus, combinando sinónimos y operadores booleanos (AND, OR). Incluye también 5-8 palabras clave alternativas que debería considerar.

# %% [markdown]
# **Pega aquí las cadenas de búsqueda que te sugirió la IA:***(pega aquí)*

# %% [markdown]
# ### 1.3 Ejecutar la búsqueda de verdadVe a **Google Scholar** (scholar.google.com) o el buscador académico que uses normalmente, y prueba una de las cadenas que generaste. Anota cuántos resultados te dio y si parecen relevantes.

# %% [markdown]
# **Resultado de tu búsqueda real:**- Cadena de búsqueda usada: ____________- Número aproximado de resultados: ____________- ¿Los primeros 5 resultados son relevantes? ____________

# %% [markdown]
# ---### 🧪 Ejercicio 1 — Refina tu estrategiaSi la búsqueda dio muy pocos o demasiados resultados, pídele a la IA que la ajuste (más específica o más amplia) y prueba de nuevo.

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟩 Bloque 2 (50 min) — Matriz de literatura con extracción asistida

# %% [markdown]
# ### 2.1 ¿Qué es una matriz de literatura?Es una tabla donde organizas la información clave de cada paper que revisas: autor, año, objetivo, método, hallazgo principal. Es la base de cualquier revisión de literatura seria — y hacerla a mano paper por paper es la parte más lenta del proceso.

# %% [markdown]
# ### 2.2 Elige 5 papers de tu propia áreaPueden ser papers que ya tengas leídos, o que encuentres ahora con la búsqueda del Bloque 1. Para cada uno, ten a la mano: título, autores, año, y si puedes, el resumen (abstract).

# %% [markdown]
# ### 2.3 Prompt para extracción asistidaPara cada paper, usa este prompt (pega el abstract o resumen del paper real):> "Aquí está el abstract de un paper académico: [pega el abstract]. Extrae en formato de tabla: (1) objetivo del estudio, (2) metodología usada, (3) hallazgo principal, (4) limitación mencionada. Sé conciso, máximo 1 línea por campo.

# %% [markdown]
# **Pega aquí las extracciones de tus 5 papers (una por paper):***(pega aquí la tabla o lista de cada paper)*

# %% [markdown]
# ### 2.4 Construir la matriz como tabla realAhora pasamos esas extracciones a una tabla de datos real, para poder comparar y filtrar.

# %%
import pandas as pd# TODO: completa con los datos de tus 5 papers (usa la extracción que hiciste arriba)matriz_literatura = pd.DataFrame({    "autor_anio": ["______", "______", "______", "______", "______"],    "objetivo": ["______", "______", "______", "______", "______"],    "metodologia": ["______", "______", "______", "______", "______"],    "hallazgo_principal": ["______", "______", "______", "______", "______"],})matriz_literatura

# %% [markdown]
# ### 2.5 Exportar tu matriz

# %%
matriz_literatura.to_csv("matriz_literatura.csv", index=False)print("Matriz guardada. Descárgala desde el panel de archivos (ícono de carpeta 📁) para usarla en tu investigación real.")

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟨 Bloque 3 (50 min) — Verificación de referencias y cierre

# %% [markdown]
# ### 3.1 ⚠️ El riesgo más importante de esta sesión: alucinaciones de referenciasLas IA generativas a veces **inventan papers que no existen** — con título, autores y año que suenan completamente reales, pero que no puedes encontrar en ningún lado. Esto se llama "alucinación", y es especialmente común cuando le pides a la IA que **te recomiende** bibliografía (en vez de que analice un texto que tú le diste).

# %% [markdown]
# ### 3.2 Cómo verificar una referenciaAntes de citar cualquier referencia que te dé una IA, verifica:1. **Busca el título exacto** en Google Scholar o Scopus — ¿aparece?2. **Verifica el DOI** (si te lo dio) en doi.org — ¿lleva a un artículo real?3. **Confirma que los autores existan** y hayan publicado sobre ese tema**Ejercicio:** pídele a una IA (Claude, ChatGPT, DeepSeek) que te recomiende 3 referencias bibliográficas sobre tu tema de investigación (sin que tú le des ningún paper de referencia). Luego verifica cada una.

# %% [markdown]
# **Resultado de tu verificación:**| Referencia sugerida por la IA | ¿Existe realmente? (Sí/No/No estoy seguro) ||---|---|| 1. | || 2. | || 3. | |

# %% [markdown]
# ### 3.3 Comparación de estudiosCon tu matriz del Bloque 2, identifica: ¿qué papers coinciden en sus hallazgos? ¿Cuáles se contradicen? ¿Qué vacío de investigación queda claro al compararlos?

# %%
# TODO/opcional: si quieres, filtra o agrupa tu matriz_literatura para comparar# Ejemplo: matriz_literatura[matriz_literatura["metodologia"].str.contains("experimental")]

# %% [markdown]
# ---## ✅ Cierre de la sesiónHoy lograste:- ✅ Diseñar una estrategia de búsqueda con ayuda de IA- ✅ Construir una matriz de literatura con extracción asistida- ✅ Aprender a detectar y verificar referencias posiblemente inventadas por la IA- ✅ Comparar hallazgos entre estudios usando tu propia matriz**Mensaje clave:** la IA acelera muchísimo la lectura y organización de literatura, pero **la verificación de que las referencias existen es innegociable** — nunca cites algo que no confirmaste tú mismo.**Para la próxima sesión (Machine Learning aplicado):** vamos a usar estos mismos principios de "generar + verificar" para entrenar modelos predictivos simples.📎 Recuerda: `Archivo → Guardar una copia en Drive` para no perder tu trabajo.

# %% [markdown]
# # Sesión 1 — Introducción, entorno de trabajo y fundamentos de programación científica**Curso:** Programación Científica con Inteligencia Artificial para la Investigación**Duración:** 3 horas (2 bloques de 50 min + cierre, con descansos de 15 min)## Objetivo de la sesiónAl terminar esta sesión podrás:- Entender qué es Google Colab y por qué lo usaremos en todo el curso- Reconocer variables y tipos de datos básicos en Python- Cargar un archivo de datos (tuyo o de ejemplo) y ver su contenido- Calcular tus primeras estadísticas simples (promedio, máximo, mínimo)> 💡 **Idea clave de todo el curso:** lo que hoy haces en Excel, SPSS o Minitab con clics, aquí lo harás con código — gratis, reproducible, y sin depender de una licencia.> ✏️ **Este notebook tiene espacios marcados con `# TODO`. Complétalos durante la práctica. Si te trabas, revisa el notebook `_completo` de esta sesión.**

# %% [markdown]
# ---## 🟦 Bloque 1 (50 min) — Fundamentos y primeras líneas de código

# %% [markdown]
# ### 1.1 ¿Qué es Google Colab?Es un cuaderno (notebook) que corre en la nube de Google. Cada celda puede tener:- **Texto** (como esta celda, en Markdown)- **Código** (Python), que se ejecuta con el botón ▶️ o presionando `Shift + Enter`No necesitas instalar nada. Todo corre en el navegador.

# %%
# Esta es una celda de código. Ejecútala con Shift + Enter# TODO: escribe un print() que salude, con tu propio mensaje

# %% [markdown]
# ### 1.2 VariablesUna variable guarda un valor para usarlo después. Se crea así: `nombre = valor`

# %%
# TODO: crea una variable con el nombre del curso (texto) y otra con el número de participantes (entero)nombre_curso = ______numero_participantes = ______print(nombre_curso)print(numero_participantes)

# %% [markdown]
# ### 1.3 Tipos de datos básicos| Tipo | Ejemplo | Uso típico ||---|---|---|| `int` (entero) | `60` | conteos, cantidades || `float` (decimal) | `7.85` | notas, mediciones || `str` (texto) | `"Ana Torres"` | nombres, categorías || `bool` (verdadero/falso) | `True` | condiciones |

# %%
nota = 8.5nombre = "Ana Torres"aprobado = True# TODO: usa type() para imprimir el tipo de cada una de las 3 variables de arriba

# %% [markdown]
# ### 1.4 Operaciones básicas

# %%
parcial1 = 7.5parcial2 = 8.2# TODO: calcula el promedio de parcial1 y parcial2promedio = ______print("Promedio:", promedio)

# %% [markdown]
# ---### 🧪 Ejercicio 1 — Practica con tus propios datosPiensa en dos calificaciones o mediciones que manejes en tu área (por ejemplo, dos evaluaciones de un estudiante, dos mediciones de un experimento). Crea las variables y calcula el promedio.

# %%
# Crea tus propias variables aquí y calcula el promediovalor1 = ______   # reemplaza con tu datovalor2 = ______   # reemplaza con tu datopromedio_propio = ______print("Mi promedio:", promedio_propio)

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟩 Bloque 2 (50 min) — Cargando datos reales con Pandas

# %% [markdown]
# ### 2.1 ¿Qué es Pandas?Es la librería de Python para manejar tablas de datos (como una hoja de Excel, pero programable). La cargamos así:

# %%
# TODO: importa pandas con el alias pd

# %% [markdown]
# ### 2.2 Cargar un archivo de datosTienes dos opciones:**Opción A — Usar el dataset de ejemplo del curso** (directo desde GitHub):

# %%
url = "https://raw.githubusercontent.com/TU-USUARIO/curso-programacion-cientifica-ia/main/datasets/ejemplo_notas.csv"# TODO: usa pd.read_csv() para cargar la url en una variable llamada 'datos'datos = ______datos.head()

# %% [markdown]
# **Opción B — Subir tu propio archivo CSV o Excel:**1. Haz clic en el ícono de carpeta 📁 en el panel izquierdo2. Haz clic en el ícono de subir archivo3. Selecciona tu archivo desde tu computador4. Carga el archivo con el nombre exacto que aparece en el panel

# %%
# Si subiste tu propio archivo, reemplaza el nombre entre comillas# datos = pd.read_csv("nombre_de_tu_archivo.csv")# datos.head()

# %% [markdown]
# ### 2.3 Explorar la tabla

# %%
# TODO: imprime la forma de la tabla (filas, columnas) con .shape# TODO: imprime la lista de columnas con .columns

# %%
# TODO: usa .describe() para ver estadísticas generales de la tabla

# %% [markdown]
# ---### 🧪 Ejercicio 2 — Estadísticas básicas de tu tablaUsa las columnas numéricas de tu tabla (o de `ejemplo_notas.csv`) para responder:

# %%
# TODO: calcula el promedio de la columna 'nota_parcial1' con .mean()promedio_p1 = ______print("Promedio parcial 1:", promedio_p1)# TODO: calcula el máximo de la columna 'nota_parcial2' con .max()maximo_p2 = ______print("Máximo parcial 2:", maximo_p2)

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟨 Bloque 3 (50 min) — Primer análisis por grupo + cierre

# %% [markdown]
# ### 3.1 Agrupar y compararUna de las tareas más comunes en investigación: comparar promedios entre grupos (por ejemplo, grupo A vs grupo B, o facultad vs facultad).

# %%
# TODO: agrupa por la columna 'grupo' y calcula el promedio de 'nota_parcial1'promedio_por_grupo = datos.groupby(______)[______].mean()print(promedio_por_grupo)

# %% [markdown]
# ### 3.2 Comparación rápida: esto vs. tu software actual| Tarea | En Excel/SPSS | Aquí (Python) ||---|---|---|| Promedio por grupo | Tabla dinámica, varios clics | 1 línea de código || Reproducir el análisis mañana | Rehacer los clics | Ejecutar la misma celda || Compartir el análisis exacto | Enviar el archivo (con licencia) | Compartir el notebook (gratis, para cualquiera) |

# %% [markdown]
# ---### 🧪 Ejercicio final — Con tus propios datosCalcula el promedio de una columna numérica de tu tabla, agrupado por otra columna categórica (por ejemplo: facultad, grupo, sexo, sede, lo que corresponda a tu área).

# %%
# TODO: reemplaza 'columna_categoria' y 'columna_numero' con los nombres reales de tu tablaresultado = datos.groupby("______")["______"].mean()print(resultado)

# %% [markdown]
# ---## ✅ Cierre de la sesiónHoy lograste:- ✅ Ejecutar tu primer código en Python- ✅ Crear variables y reconocer tipos de datos- ✅ Cargar una tabla de datos (tuya o de ejemplo) en Colab- ✅ Calcular promedios simples y por grupo**Para la próxima sesión:** trae (si puedes) un archivo CSV o Excel real de tu investigación o práctica docente — lo usaremos para todo el resto del curso.📎 Recuerda: `Archivo → Guardar una copia en Drive` para no perder tu trabajo.

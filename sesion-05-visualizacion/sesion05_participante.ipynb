# %% [markdown]
# # Sesión 5 — Visualización y comunicación científica**Temas:** selección de gráficos, Matplotlib, construcción, personalización y exportación de figuras**Duración:** 3 horas (2 bloques de 50 min + cierre, con descansos de 15 min)## Objetivo de la sesión- Elegir el tipo de gráfico correcto según lo que quieres mostrar- Construir y personalizar gráficos con Matplotlib (títulos, ejes, colores, leyenda)- Exportar figuras en calidad de publicación, listas para un informe o artículo> 💡 Esto reemplaza lo que haces en Excel/Origin/GraphPad para generar gráficos — con más control y sin límite de licencia.> ✏️ Este notebook tiene espacios marcados con `# TODO`. Complétalos durante la práctica. Si te trabas, revisa el notebook `_completo` de esta sesión.

# %%
import pandas as pdimport matplotlib.pyplot as plt# TODO: reemplaza por el link "raw" del dataset de TU áreaurl = "https://raw.githubusercontent.com/TU-USUARIO/curso-programacion-cientifica-ia/main/datasets/ejemplo_notas.csv"datos = ______datos.head()

# %% [markdown]
# ---## 🟦 Bloque 1 (50 min) — Elegir y construir el gráfico correcto

# %% [markdown]
# ### 1.1 ¿Qué gráfico uso según lo que quiero mostrar?| Quiero mostrar... | Uso este gráfico ||---|---|| Comparar un valor entre categorías (ej. promedio por facultad) | Barras || Relación entre dos variables numéricas | Dispersión (scatter) || Distribución y valores atípicos de una variable | Caja (boxplot) || Evolución en el tiempo | Línea |

# %% [markdown]
# ### 1.2 Gráfico de barras: promedio por grupo

# %%
# TODO: calcula el promedio de 'nota_parcial1' agrupado por 'facultad'promedio_facultad = datos.groupby("______")["______"].mean()plt.bar(promedio_facultad.index, promedio_facultad.values)plt.show()

# %% [markdown]
# ### 1.3 Gráfico de dispersión: relación entre dos variables

# %%
# TODO: usa plt.scatter() con 'nota_parcial1' en x y 'nota_parcial2' en yplt.scatter(datos["______"], datos["______"])plt.show()

# %% [markdown]
# ---### 🧪 Ejercicio 1 — Grafica tu propia baseCon tu dataset (o el de tu área), haz un gráfico de barras del promedio por grupo o facultad.

# %%
# Tu gráfico de barras aquí

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟩 Bloque 2 (50 min) — Personalización: títulos, ejes, colores, leyenda

# %% [markdown]
# ### 2.1 Un gráfico "desnudo" no sirve para un informeSin título ni ejes etiquetados, nadie más que tú entiende qué representa. Vamos a vestirlo correctamente.

# %%
promedio_facultad = datos.groupby("facultad")["nota_parcial1"].mean()plt.bar(promedio_facultad.index, promedio_facultad.values, color="steelblue")# TODO: agrega plt.title(), plt.xlabel() y plt.ylabel() con textos descriptivosplt.title("______")plt.xlabel("______")plt.ylabel("______")plt.xticks(rotation=30)plt.tight_layout()plt.show()

# %% [markdown]
# ### 2.2 Comparar dos series con leyendaÚtil para mostrar, por ejemplo, `nota_parcial1` vs `nota_parcial2` por facultad, uno al lado del otro.

# %%
resumen = datos.groupby("facultad")[["nota_parcial1", "nota_parcial2"]].mean()x = range(len(resumen))ancho = 0.35plt.bar([i - ancho/2 for i in x], resumen["nota_parcial1"], width=ancho, label="Parcial 1")# TODO: agrega la segunda barra para 'nota_parcial2', desplazada +ancho/2, con su propio labelplt.bar(______, resumen["nota_parcial2"], width=ancho, label="______")plt.xticks(list(x), resumen.index, rotation=30)plt.legend()plt.title("Comparación de parciales por facultad")plt.tight_layout()plt.show()

# %% [markdown]
# ### 2.3 Boxplot: distribución y valores atípicos por grupo

# %%
grupos_datos = [grupo["nota_parcial1"].values for nombre, grupo in datos.groupby("grupo")]etiquetas = datos["grupo"].unique()# TODO: usa plt.boxplot() pasando grupos_datos, con labels=etiquetasplt.boxplot(______, labels=______)plt.title("Distribución de nota parcial 1 por grupo")plt.ylabel("Nota parcial 1")plt.show()

# %% [markdown]
# ---### 🧪 Ejercicio 2 — Personaliza un gráfico con tus datosToma el gráfico de barras del Ejercicio 1 y agrégale título, etiquetas de eje y color.

# %%
# Tu gráfico personalizado aquí

# %% [markdown]
# ---## ☕ Descanso — 15 minutos

# %% [markdown]
# ---## 🟨 Bloque 3 (50 min) — Exportar en calidad de publicación y cierre

# %% [markdown]
# ### 3.1 Guardar la figura como archivo`dpi=300` es el estándar mínimo que piden la mayoría de revistas científicas para figuras.

# %%
promedio_facultad = datos.groupby("facultad")["nota_parcial1"].mean()plt.bar(promedio_facultad.index, promedio_facultad.values, color="steelblue")plt.title("Promedio de nota parcial 1 por facultad")plt.xlabel("Facultad")plt.ylabel("Promedio")plt.xticks(rotation=30)plt.tight_layout()# TODO: usa plt.savefig() con dpi=300 para exportar como PNG______plt.show()print("Archivo guardado. Búscalo en el panel de archivos de la izquierda (ícono de carpeta 📁).")

# %% [markdown]
# ### 3.2 Formatos según el uso| Formato | Cuándo usarlo ||---|---|| PNG | Informes, presentaciones, Word || SVG | Cuando necesitas editar el gráfico después en otro programa (escalable sin perder calidad) || PDF | Publicaciones académicas (algunas revistas lo piden) |Solo cambia la extensión en `plt.savefig("grafico.svg")` o `plt.savefig("grafico.pdf")`.

# %% [markdown]
# ---### 🧪 Ejercicio final — Tu figura lista para publicaciónToma cualquier gráfico que hiciste hoy con tus propios datos, agrégale título y etiquetas, y expórtalo en PNG a 300 dpi.

# %%
# Tu figura final, lista para exportar

# %% [markdown]
# ---## ✅ Cierre de la sesiónHoy lograste:- ✅ Elegir el tipo de gráfico correcto según el mensaje que quieres dar- ✅ Construir barras, dispersión y boxplots- ✅ Personalizar títulos, etiquetas, colores y leyendas- ✅ Exportar en calidad de publicación (300 dpi)**Para la próxima sesión (IA generativa):** vamos a usar IA para acelerar tareas de programación e investigación — incluyendo un ejercicio práctico con sílabos.📎 Recuerda: `Archivo → Guardar una copia en Drive` para no perder tu trabajo.

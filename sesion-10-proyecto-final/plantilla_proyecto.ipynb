# %% [markdown]
# # 🎯 Proyecto Integrador — Programación Científica con IA para la Investigación**Nombre del participante:** ____________________**Área / Facultad:** ____________________**Tema del proyecto:** ____________________## InstruccionesEsta plantilla reúne todo lo que trabajaste en las Sesiones 1-9. Complétala con tu propio dataset (o el de tu área) y tu propio tema de investigación o práctica docente. No necesitas usar absolutamente todas las secciones si alguna no aplica a tu caso — pero mientras más completa, mejor refleja lo aprendido.**Tiempo sugerido:** usa el Bloque 1 de esta sesión para completar la plantilla; los Bloques 2 y 3 son para presentar y cerrar.

# %% [markdown]
# ---## 1. Introducción**¿Cuál es la pregunta o problema que quieres explorar con tus datos?***(escribe 2-3 líneas: contexto, por qué importa para tu área)*

# %% [markdown]
# ---## 2. Carga y limpieza de datos*(Sesiones 1 y 3)*

# %%
import pandas as pdimport numpy as npimport matplotlib.pyplot as pltfrom scipy import stats# Carga tu dataset (propio o el de tu área)url = "https://raw.githubusercontent.com/TU-USUARIO/curso-programacion-cientifica-ia/main/datasets/TU_ARCHIVO.csv"datos = pd.read_csv(url)datos.head()

# %%
# Diagnóstico y limpieza (adapta según lo que necesite tu base)print(datos.info())print(datos.isna().sum())print("Duplicados:", datos.duplicated().sum())# Aplica aquí tus pasos de limpieza si los necesitas

# %% [markdown]
# ---## 3. Estadística descriptiva y comparación de grupos*(Sesión 4)*

# %%
# Estadística descriptivadatos.describe()

# %%
# Comparación de grupos (ajusta las columnas a tu base)# grupo_a = datos[datos["grupo"] == "A"]["tu_columna_numerica"]# grupo_b = datos[datos["grupo"] == "B"]["tu_columna_numerica"]# t_valor, p_valor = stats.ttest_ind(grupo_a, grupo_b)# print("Valor p:", p_valor)

# %% [markdown]
# ---## 4. Visualización*(Sesión 5)*

# %%
# Al menos un gráfico que resuma tu hallazgo principal# plt.bar(...) / plt.scatter(...) / plt.boxplot(...)# plt.title("...")# plt.xlabel("...")# plt.ylabel("...")# plt.savefig("mi_grafico_final.png", dpi=300)# plt.show()

# %% [markdown]
# ---## 5. Uso de IA generativa en este proyecto*(Sesión 6)***¿En qué parte de este proyecto usaste IA (Gemini, Claude, ChatGPT, DeepSeek)?***(ej. "usé IA para generar el código del gráfico de barras y para redactar la interpretación de resultados")***¿Qué verificaste antes de confiar en el resultado?***(escribe aquí)*

# %% [markdown]
# ---## 6. Revisión de literatura (si aplica a tu proyecto)*(Sesión 7)*Si tu proyecto se conecta con una investigación o tesis, incluye tu mini-matriz de literatura aquí (puedes pegar la tabla que armaste en la Sesión 7).

# %%
# Si armaste una matriz de literatura en la Sesión 7, puedes cargarla aquí# matriz = pd.read_csv("matriz_literatura.csv")# matriz

# %% [markdown]
# ---## 7. Modelo predictivo (opcional)*(Sesión 8 — inclúyelo solo si tiene sentido para tu proyecto)*

# %%
# from sklearn.model_selection import train_test_split# from sklearn.linear_model import LinearRegression# ... (adapta el código de la Sesión 8 a tu caso)

# %% [markdown]
# ---## 8. Declaración de reproducibilidad y ética*(Sesión 9)***Enlace a tu repositorio de GitHub:** ____________________**Declaración de uso de IA para este proyecto:***(usa el formato de la Sesión 9, Bloque 2)***¿Tus datos requieren alguna consideración de privacidad?** Sí / No — *(si sí, ¿cómo la manejaste?)*

# %% [markdown]
# ---## 9. Conclusiones**¿Qué encontraste?** (2-4 líneas, en lenguaje claro, como si se lo explicaras a un colega de tu facultad)*(escribe aquí)***¿Qué harías distinto si tuvieras más tiempo o más datos?***(escribe aquí)***¿Cómo vas a seguir usando esto después del curso?***(escribe aquí — esto es lo más importante de toda la plantilla)*

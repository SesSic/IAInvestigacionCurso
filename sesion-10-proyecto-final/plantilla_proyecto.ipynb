# %% [markdown]
# # Proyecto integrador — [Escribe el título de tu proyecto aquí]**Autor:** [tu nombre]**Área:** [tu área/facultad]**Fecha:** [fecha]Esta plantilla está intencionalmente en blanco — la estructura es una guía narrativa, no un ejercicio con respuestas fijas. Bórrala o adáptala según lo que tu proyecto realmente necesite. Revisa `PROYECTO_FINAL_GUIA.md` en esta misma carpeta si necesitas orientación.

# %% [markdown]
# ---## 1. El problema*(1-2 párrafos: ¿qué querías resolver o automatizar? ¿por qué te importa a ti, en tu trabajo/investigación real?)*Escribe aquí...

# %% [markdown]
# ---## 2. Los datos (o la tarea, si no usas datos numéricos)*(¿De dónde vienen tus datos? ¿Cuántos registros/casos tienes? Si tu proyecto no usa datos numéricos —por ejemplo, es una matriz de literatura o un sílabo generado con IA— describe aquí qué insumos usaste.)*Escribe aquí...

# %%
# Si usas datos, cárgalos aquíimport pandas as pd# datos = pd.read_csv("tu_archivo.csv")# datos.head()

# %% [markdown]
# ---## 3. Proceso*(Aquí va tu trabajo real: limpieza, análisis, visualización, modelo, prompts de IA que usaste, lo que corresponda. Agrega tantas celdas de código y texto como necesites. Explica cada paso en una celda de texto antes del código, como si alguien más fuera a leerlo sin que tú se lo expliques en persona.)*

# %% [markdown]
# ### 3.1 [Nombra tu primer paso, ej. "Limpieza de datos" o "Estrategia de búsqueda"]

# %%
# Tu código aquí

# %% [markdown]
# ### 3.2 [Nombra tu siguiente paso]

# %%
# Tu código aquí

# %% [markdown]
# ### 3.3 [Agrega más secciones según necesites — 3.4, 3.5, etc.]

# %%
# Tu código aquí

# %% [markdown]
# ---## 4. Si usaste IA generativa*(¿Qué prompts usaste? ¿Qué tuviste que corregir o verificar de lo que te dio la IA? Este paso es parte de la evaluación — muestra tu criterio, no solo el resultado.)*Escribe aquí...

# %% [markdown]
# ---## 5. Resultado*(¿Qué encontraste, generaste o lograste? Puede ser un gráfico, una tabla, un modelo, un documento — lo que corresponda a tu proyecto.)*

# %%
# Muestra tu resultado final aquí (gráfico, tabla, print, lo que aplique)

# %% [markdown]
# ---## 6. Conclusión y próximos pasos*(3-5 líneas: ¿qué significa este resultado para tu trabajo? ¿Cómo piensas seguir usando esto después del curso? ¿Qué harías distinto si lo repitieras?)*Escribe aquí...

# %% [markdown]
# ---## ✅ Antes de presentar, revisa:- [ ] ¿Alguien más podría entender tu notebook sin que tú se lo expliques?- [ ] Si usaste IA, ¿quedó claro qué verificaste o corregiste?- [ ] ¿Tu conclusión responde a la pregunta que planteaste en la Sección 1?- [ ] ¿Guardaste tu copia en Drive? (`Archivo → Guardar una copia en Drive`)
